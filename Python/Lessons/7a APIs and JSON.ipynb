# %% [markdown]
# # APIs and JSON

# %% [markdown]
# ### What is an API

# %% [markdown]
# An API, acronym for **Application Programming Interface**, is simply a software interface that **allows two applications to talk to each other**. Unlike a user interface, which connects a computer to a person, an application programming interface connects computers or pieces of software to each other. Although it is not meant to be used directly by the end user, data analysts and data scientists may use and test it directly before implementing it into their program/analysis.

# %% [markdown]
# <img src="img/what-is-api.png" width="600">

# %% [markdown]
# ### API Analogy
#
# Imagine that you're the owner of a store and you're on holiday at the beach. Although you should be relaxing, you're concerned about your business, so you instruct your friend to call the store at the end of every day and ask how many customers came and purchased something and then write it down on a blackboard next to your beachbed.
#
# This would be a real-world analogy of how an API works:
#
# - the two computers or pieces of software are the blackboard on your end (usually a browser, web app or script) and the store on the other side (usually a web server/database)
# - your friend is the intermediary who is doing the work of the API in connecting the two:
#     - he sends a request
#     - waits for a result
#     - then writes the result on the board
# - notice that you are not phisically making the request, you have instructed your friend, just like you write instructions for your program

# %% [markdown]
# ### API example
#
# You could write a script that asks the end user for a city name and, using a Google Maps API, returns the latitude and longitude coordinates of that city. Let's see how this process would work:
#
# - The end user starts the program, the program asks the user for a city name, which he enters in the prompt box
# - The program receives the city name in input and, via the Google Maps API, sends a request to Google's web server
# - Google's web server receives the request and queries its database to find the relative result
# - Meanwhile, the API is waiting for this result
# - once the web server returns the result, the API sends it back to the requesting program (the one you wrote)
# - the resulting latitude and longitude coordinates are then showed to the end user

# %% [markdown]
# Although there are [different types of APIs](https://en.wikipedia.org/wiki/API#Usage), we will focus on Web APIs. These are programs that use an internet address (like a URL), to provide access to their services.

# %% [markdown]
# ### Your first API call
#
# Let's look at a practical case. The city of Milan has a rich [Open Data portal](https://dati.comune.milano.it/) where you can access its data in several ways, namely by:
# - downloading a file
# - retrieving the data via an API call
#
# When we say "API call", we mean that we are **sending a request** via the API (just like we were sending our friend to phone the store in our previous analogy).

# %% [markdown]
# For example, [at this page](https://dati.comune.milano.it/dataset/ds1573-gas-erogato-a2a-totale-giornaliero) we can find the **daily total gas delivered by A2A** (an italian energy provider) in cubic meters. As you can see, there are **two data formats** available, csv and json.
#
# If we click on the csv option, we are redirected to [this page](https://dati.comune.milano.it/dataset/ds1573-gas-erogato-a2a-totale-giornaliero/resource/dbd7417a-41e8-4097-a1c4-67094983bab1), where we can **see the data in a table** and we can either download the data on our computer (see the red button that says "Download") in a specified format (csv, tsv, json or xml) or we can **retrieve the data using their API** (see the green button that says "Data API").
#
# If you **click on the green button** that says `Data API`, a pop-up will be opened and you'll be able to see the URL that can be used to perform the API call *(note: this is also known as the [API endpoint](https://kinsta.com/knowledgebase/api-endpoint/#understanding-api-endpoints))* as well as some examples to get you started. For instance, if you **copy the following URL and paste it in your browser**, you will see the result of the API call in your browser, showing you the first 5 records of the data you were trying to retrieve ([click here](https://dati.comune.milano.it/api/3/action/datastore_search?resource_id=dbd7417a-41e8-4097-a1c4-67094983bab1&limit=5) to try it yourself!):
#
#     https://dati.comune.milano.it/api/3/action/datastore_search?resource_id=dbd7417a-41e8-4097-a1c4-67094983bab1&limit=5

# %% [markdown]
# Now, before we proceed any further, there are **a couple of observations** to be made:
# 1. The result we're obtaining looks a little messy... what are all those curly brackets?
# 2. Didn't we say that APIs are not meant to be used directly by the end user?
#
# Let's start by addressing the first point.

# %% [markdown]
# ### JSON

# %% [markdown]
# The strange, messy format of the result from our API call is called **JSON**, which is an acronym that stands for **JavaScript Object Notation**.
#
# According to [Wikipedia](https://en.wikipedia.org/wiki/JSON), *it is an open standard file format and data interchange format that uses human-readable text to store and transmit data objects consisting of attribute–value pairs and arrays*.
#
# Let's unpack the previous sentence:
# - it's a **file format** (just like a .csv file)
# - it **stores data**
# - the data is stored in **attribute-value** pairs
#
# So, it's just another way of storing data, like a csv or a text file, but it stores it using a method that should be familiar to you: the attribute-value pair works just like the key-value pairs from Python's dictionaries that we have seen at the beginning of this Module.

# %% [markdown]
# Now, the Wikipedia definition said also that the contents of the JSON is human readable and, looking at the API result, one could understandably argue against that statement. However, if we copy that result and paste it in a **JSON formatter** like [this one](https://jsonformatter.org/), you will see that **its readability improves** quite dramatically. Check out the example below to get a better idea of this particular data format:
#
# <img src="img/json.png" width="900">
#
# Although to a human it is not as readable as a csv file, its **nested hierarchical structure** allows you to include all kind of metadata next to the data itself. It takes time and practice to get used to this data format, so don't get discouraged if you're finding it harder than expected.
#
# Check out [this article](https://realpython.com/python-json/) to find out more about JSON data structures in relation to Python.

# %% [markdown]
# Let's now address the second observation from the previous section: APIs are meant to be used by a program, not to be typed in the address bar of a web browser. In the next section we'll look at how we can **make an API call in Python**.

# %% [markdown]
# ### API calls in Python

# %% [markdown]
# #### City of Milan API

# %% [markdown]
# Now we have all the necessary pieces to get started and make our first API call in Python. To do that, we'll need to load the `requests` [library](https://requests.readthedocs.io/en/latest/), whose goal is to make **HTTP requests in Python** simpler and more human-friendly (as stated also in the tagline of the library's logo).

# %%
import numpy as np
import pandas as pd

# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

import requests

# %%
# save the URL string (without the limit=5 parameter) to a "url" object
url = 'https://dati.comune.milano.it/api/3/action/datastore_search?resource_id=dbd7417a-41e8-4097-a1c4-67094983bab1&limit=1000'

# %% [markdown]
# The **GET** [HTTP method](https://www.w3schools.com/tags/ref_httpmethods.asp) allows you to request data from a specified resource or server. In the `requests` library this can be achieved via the `get()` function:

# %%
# make the HTTP request
r = requests.get(url)

# %%
type(r)
# Out:
# requests.models.Response

# %% [markdown]
# Every time you send a request, you will expect some data in return. Together with your data, **you will also receive a status code**, telling you whether the request was successful. Make sure to always check the status of your request via the `.status_code` attribute and to **verify the meaning** of that status. A status of 200 means that the request was successful, check [this page](https://en.wikipedia.org/wiki/List_of_HTTP_status_codes#1xx_informational_response) for a complete list of statuses.

# %%
# check the status code of your HTTP request
r.status_code
# Out:
# 200

# %% [markdown]
# If you're dealing with json data, you can **explore the contents of your result** using the `.json` attribute:

# %%
r.json()
# Out:
# {'help': 'https://dati.comune.milano.it/api/3/action/help_show?name=datastore_search',
#  'success': True,
#  'result': {'include_total': True,
#   'resource_id': 'dbd7417a-41e8-4097-a1c4-67094983bab1',
#   'fields': [{'type': 'int', 'id': '_id'},
#    {'info': {'notes': '', 'type_override': '', 'label': ''},
#     'type': 'numeric',
#     'id': 'Anno'},
#    {'info': {'notes': '', 'type_override': '', 'label': ''},
#     'type': 'timestamp',
#     'id': 'Data'},
#    {'info': {'notes': '', 'type_override': '', 'label': ''},
#     'type': 'text',
#     'id': 'Giorno'},
#    {'info': {'notes': '', 'type_override': 'numeric', 'label': ''},
#     'type': 'numeric',
#     'id': 'Totale (Smc)'}],
#   'records_format': 'objects',
#   'records': [{'_id': 1,
#     'Anno': 2019,
#     'Data': '2019-01-01T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 6603230},
#    {'_id': 2,
#     'Anno': 2019,
#     'Data': '2019-01-02T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 6579016},
#    {'_id': 3,
#     'Anno': 2019,
#     'Data': '2019-01-03T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 7115704},
#    {'_id': 4,
#     'Anno': 2019,
#     'Data': '2019-01-04T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 7650062},
#    {'_id': 5,
#     'Anno': 2019,
#     'Data': '2019-01-05T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 7471068},
#    {'_id': 6,
#     'Anno': 2019,
#     'Data': '2019-01-06T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 6764308},
#    {'_id': 7,
#     'Anno': 2019,
#     'Data': '2019-01-07T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 7406714},
#    {'_id': 8,
#     'Anno': 2019,
#     'Data': '2019-01-08T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 7697269},
#    {'_id': 9,
#     'Anno': 2019,
#     'Data': '2019-01-09T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 7289985},
#    {'_id': 10,
#     'Anno': 2019,
#     'Data': '2019-01-10T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 6942742},
#    {'_id': 11,
#     'Anno': 2019,
#     'Data': '2019-01-11T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 7330613},
#    {'_id': 12,
#     'Anno': 2019,
#     'Data': '2019-01-12T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 7093254},
#    {'_id': 13,
#     'Anno': 2019,
#     'Data': '2019-01-13T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 6839856},
#    {'_id': 14,
#     'Anno': 2019,
#     'Data': '2019-01-14T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 6152034},
#    {'_id': 15,
#     'Anno': 2019,
#     'Data': '2019-01-15T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 6340289},
#    {'_id': 16,
#     'Anno': 2019,
#     'Data': '2019-01-16T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 6186696},
#    {'_id': 17,
#     'Anno': 2019,
#     'Data': '2019-01-17T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 6469788},
#    {'_id': 18,
#     'Anno': 2019,
#     'Data': '2019-01-18T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 6808083},
#    {'_id': 19,
#     'Anno': 2019,
#     'Data': '2019-01-19T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 6641610},
#    {'_id': 20,
#     'Anno': 2019,
#     'Data': '2019-01-20T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 6932744},
#    {'_id': 21,
#     'Anno': 2019,
#     'Data': '2019-01-21T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 7580166},
#    {'_id': 22,
#     'Anno': 2019,
#     'Data': '2019-01-22T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 7743969},
#    {'_id': 23,
#     'Anno': 2019,
#     'Data': '2019-01-23T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 8174702},
#    {'_id': 24,
#     'Anno': 2019,
#     'Data': '2019-01-24T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 7846440},
#    {'_id': 25,
#     'Anno': 2019,
#     'Data': '2019-01-25T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 7846087},
#    {'_id': 26,
#     'Anno': 2019,
#     'Data': '2019-01-26T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 7392830},
#    {'_id': 27,
#     'Anno': 2019,
#     'Data': '2019-01-27T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 7616016},
#    {'_id': 28,
#     'Anno': 2019,
#     'Data': '2019-01-28T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 7553369},
#    {'_id': 29,
#     'Anno': 2019,
#     'Data': '2019-01-29T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 7524599},
#    {'_id': 30,
#     'Anno': 2019,
#     'Data': '2019-01-30T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 7848960},
#    {'_id': 31,
#     'Anno': 2019,
#     'Data': '2019-01-31T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 8073122},
#    {'_id': 32,
#     'Anno': 2019,
#     'Data': '2019-02-01T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 8861184},
#    {'_id': 33,
#     'Anno': 2019,
#     'Data': '2019-02-02T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 8078085},
#    {'_id': 34,
#     'Anno': 2019,
#     'Data': '2019-02-03T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 7717585},
#    {'_id': 35,
#     'Anno': 2019,
#     'Data': '2019-02-04T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 7618516},
#    {'_id': 36,
#     'Anno': 2019,
#     'Data': '2019-02-05T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 7617265},
#    {'_id': 37,
#     'Anno': 2019,
#     'Data': '2019-02-06T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 7457558},
#    {'_id': 38,
#     'Anno': 2019,
#     'Data': '2019-02-07T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 7798382},
#    {'_id': 39,
#     'Anno': 2019,
#     'Data': '2019-02-08T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 7245421},
#    {'_id': 40,
#     'Anno': 2019,
#     'Data': '2019-02-09T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 6542627},
#    {'_id': 41,
#     'Anno': 2019,
#     'Data': '2019-02-10T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 6774689},
#    {'_id': 42,
#     'Anno': 2019,
#     'Data': '2019-02-11T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 6925386},
#    {'_id': 43,
#     'Anno': 2019,
#     'Data': '2019-02-12T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 6377350},
#    {'_id': 44,
#     'Anno': 2019,
#     'Data': '2019-02-13T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 6535263},
#    {'_id': 45,
#     'Anno': 2019,
#     'Data': '2019-02-14T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 6475077},
#    {'_id': 46,
#     'Anno': 2019,
#     'Data': '2019-02-15T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 6093690},
#    {'_id': 47,
#     'Anno': 2019,
#     'Data': '2019-02-16T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 5632209},
#    {'_id': 48,
#     'Anno': 2019,
#     'Data': '2019-02-17T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 5452881},
#    {'_id': 49,
#     'Anno': 2019,
#     'Data': '2019-02-18T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 5690448},
#    {'_id': 50,
#     'Anno': 2019,
#     'Data': '2019-02-19T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 5665280},
#    {'_id': 51,
#     'Anno': 2019,
#     'Data': '2019-02-20T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 5987828},
#    {'_id': 52,
#     'Anno': 2019,
#     'Data': '2019-02-21T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 5730852},
#    {'_id': 53,
#     'Anno': 2019,
#     'Data': '2019-02-22T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 5130655},
#    {'_id': 54,
#     'Anno': 2019,
#     'Data': '2019-02-23T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 5951766},
#    {'_id': 55,
#     'Anno': 2019,
#     'Data': '2019-02-24T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 6071045},
#    {'_id': 56,
#     'Anno': 2019,
#     'Data': '2019-02-25T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 6026920},
#    {'_id': 57,
#     'Anno': 2019,
#     'Data': '2019-02-26T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 5311908},
#    {'_id': 58,
#     'Anno': 2019,
#     'Data': '2019-02-27T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 4665319},
#    {'_id': 59,
#     'Anno': 2019,
#     'Data': '2019-02-28T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 4535871},
#    {'_id': 60,
#     'Anno': 2019,
#     'Data': '2019-03-01T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 4470330},
#    {'_id': 61,
#     'Anno': 2019,
#     'Data': '2019-03-02T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 4251066},
#    {'_id': 62,
#     'Anno': 2019,
#     'Data': '2019-03-03T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 4102244},
#    {'_id': 63,
#     'Anno': 2019,
#     'Data': '2019-03-04T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 5304389},
#    {'_id': 64,
#     'Anno': 2019,
#     'Data': '2019-03-05T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 4953319},
#    {'_id': 65,
#     'Anno': 2019,
#     'Data': '2019-03-06T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 5008642},
#    {'_id': 66,
#     'Anno': 2019,
#     'Data': '2019-03-07T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 4757596},
#    {'_id': 67,
#     'Anno': 2019,
#     'Data': '2019-03-08T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 4295680},
#    {'_id': 68,
#     'Anno': 2019,
#     'Data': '2019-03-09T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 3900886},
#    {'_id': 69,
#     'Anno': 2019,
#     'Data': '2019-03-10T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 3836885},
#    {'_id': 70,
#     'Anno': 2019,
#     'Data': '2019-03-11T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 4920139},
#    {'_id': 71,
#     'Anno': 2019,
#     'Data': '2019-03-12T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 5144200},
#    {'_id': 72,
#     'Anno': 2019,
#     'Data': '2019-03-13T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 5014575},
#    {'_id': 73,
#     'Anno': 2019,
#     'Data': '2019-03-14T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 4881277},
#    {'_id': 74,
#     'Anno': 2019,
#     'Data': '2019-03-15T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 4006985},
#    {'_id': 75,
#     'Anno': 2019,
#     'Data': '2019-03-16T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 3283153},
#    {'_id': 76,
#     'Anno': 2019,
#     'Data': '2019-03-17T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 3845431},
#    {'_id': 77,
#     'Anno': 2019,
#     'Data': '2019-03-18T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 4375780},
#    {'_id': 78,
#     'Anno': 2019,
#     'Data': '2019-03-19T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 4736615},
#    {'_id': 79,
#     'Anno': 2019,
#     'Data': '2019-03-20T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 4777663},
#    {'_id': 80,
#     'Anno': 2019,
#     'Data': '2019-03-21T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 4535466},
#    {'_id': 81,
#     'Anno': 2019,
#     'Data': '2019-03-22T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 3946367},
#    {'_id': 82,
#     'Anno': 2019,
#     'Data': '2019-03-23T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 3179729},
#    {'_id': 83,
#     'Anno': 2019,
#     'Data': '2019-03-24T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 2763954},
#    {'_id': 84,
#     'Anno': 2019,
#     'Data': '2019-03-25T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 2950514},
#    {'_id': 85,
#     'Anno': 2019,
#     'Data': '2019-03-26T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 3753546},
#    {'_id': 86,
#     'Anno': 2019,
#     'Data': '2019-03-27T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 3896804},
#    {'_id': 87,
#     'Anno': 2019,
#     'Data': '2019-03-28T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 3999182},
#    {'_id': 88,
#     'Anno': 2019,
#     'Data': '2019-03-29T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 3620750},
#    {'_id': 89,
#     'Anno': 2019,
#     'Data': '2019-03-30T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 3280864},
#    {'_id': 90,
#     'Anno': 2019,
#     'Data': '2019-03-31T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 2942129},
#    {'_id': 91,
#     'Anno': 2019,
#     'Data': '2019-04-01T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 2872943},
#    {'_id': 92,
#     'Anno': 2019,
#     'Data': '2019-04-02T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 2721134},
#    {'_id': 93,
#     'Anno': 2019,
#     'Data': '2019-04-03T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 3640068},
#    {'_id': 94,
#     'Anno': 2019,
#     'Data': '2019-04-04T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 4428823},
#    {'_id': 95,
#     'Anno': 2019,
#     'Data': '2019-04-05T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 3972527},
#    {'_id': 96,
#     'Anno': 2019,
#     'Data': '2019-04-06T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 3583492},
#    {'_id': 97,
#     'Anno': 2019,
#     'Data': '2019-04-07T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 3999847},
#    {'_id': 98,
#     'Anno': 2019,
#     'Data': '2019-04-08T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 3811880},
#    {'_id': 99,
#     'Anno': 2019,
#     'Data': '2019-04-09T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 3296666},
#    {'_id': 100,
#     'Anno': 2019,
#     'Data': '2019-04-10T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 3338065},
#    {'_id': 101,
#     'Anno': 2019,
#     'Data': '2019-04-11T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 3913936},
#    {'_id': 102,
#     'Anno': 2019,
#     'Data': '2019-04-12T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 3666572},
#    {'_id': 103,
#     'Anno': 2019,
#     'Data': '2019-04-13T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 3758314},
#    {'_id': 104,
#     'Anno': 2019,
#     'Data': '2019-04-14T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 4653675},
#    {'_id': 105,
#     'Anno': 2019,
#     'Data': '2019-04-15T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 3545861},
#    {'_id': 106,
#     'Anno': 2019,
#     'Data': '2019-04-16T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 2698381},
#    {'_id': 107,
#     'Anno': 2019,
#     'Data': '2019-04-17T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 2252356},
#    {'_id': 108,
#     'Anno': 2019,
#     'Data': '2019-04-18T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 2006385},
#    {'_id': 109,
#     'Anno': 2019,
#     'Data': '2019-04-19T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 1780672},
#    {'_id': 110,
#     'Anno': 2019,
#     'Data': '2019-04-20T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 1493997},
#    {'_id': 111,
#     'Anno': 2019,
#     'Data': '2019-04-21T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 1295303},
#    {'_id': 112,
#     'Anno': 2019,
#     'Data': '2019-04-22T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 1468468},
#    {'_id': 113,
#     'Anno': 2019,
#     'Data': '2019-04-23T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 1932729},
#    {'_id': 114,
#     'Anno': 2019,
#     'Data': '2019-04-24T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 1767394},
#    {'_id': 115,
#     'Anno': 2019,
#     'Data': '2019-04-25T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 1673887},
#    {'_id': 116,
#     'Anno': 2019,
#     'Data': '2019-04-26T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 1766341},
#    {'_id': 117,
#     'Anno': 2019,
#     'Data': '2019-04-27T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 1550605},
#    {'_id': 118,
#     'Anno': 2019,
#     'Data': '2019-04-28T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 1565769},
#    {'_id': 119,
#     'Anno': 2019,
#     'Data': '2019-04-29T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 1849225},
#    {'_id': 120,
#     'Anno': 2019,
#     'Data': '2019-04-30T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 1497722},
#    {'_id': 121,
#     'Anno': 2019,
#     'Data': '2019-05-01T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 1294014},
#    {'_id': 122,
#     'Anno': 2019,
#     'Data': '2019-05-02T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 1348742},
#    {'_id': 123,
#     'Anno': 2019,
#     'Data': '2019-05-03T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 1401707},
#    {'_id': 124,
#     'Anno': 2019,
#     'Data': '2019-05-04T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 1379781},
#    {'_id': 125,
#     'Anno': 2019,
#     'Data': '2019-05-05T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 1760672},
#    {'_id': 126,
#     'Anno': 2019,
#     'Data': '2019-05-06T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 1734311},
#    {'_id': 127,
#     'Anno': 2019,
#     'Data': '2019-05-07T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 1624691},
#    {'_id': 128,
#     'Anno': 2019,
#     'Data': '2019-05-08T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 1999356},
#    {'_id': 129,
#     'Anno': 2019,
#     'Data': '2019-05-09T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 1755754},
#    {'_id': 130,
#     'Anno': 2019,
#     'Data': '2019-05-10T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 1448270},
#    {'_id': 131,
#     'Anno': 2019,
#     'Data': '2019-05-11T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 1451439},
#    {'_id': 132,
#     'Anno': 2019,
#     'Data': '2019-05-12T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 1486403},
#    {'_id': 133,
#     'Anno': 2019,
#     'Data': '2019-05-13T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 1489702},
#    {'_id': 134,
#     'Anno': 2019,
#     'Data': '2019-05-14T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 1501595},
#    {'_id': 135,
#     'Anno': 2019,
#     'Data': '2019-05-15T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 1611766},
#    {'_id': 136,
#     'Anno': 2019,
#     'Data': '2019-05-16T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 1443196},
#    {'_id': 137,
#     'Anno': 2019,
#     'Data': '2019-05-17T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 1419596},
#    {'_id': 138,
#     'Anno': 2019,
#     'Data': '2019-05-18T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 1489767},
#    {'_id': 139,
#     'Anno': 2019,
#     'Data': '2019-05-19T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 1519626},
#    {'_id': 140,
#     'Anno': 2019,
#     'Data': '2019-05-20T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 1594652},
#    {'_id': 141,
#     'Anno': 2019,
#     'Data': '2019-05-21T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 1335252},
#    {'_id': 142,
#     'Anno': 2019,
#     'Data': '2019-05-22T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 1212208},
#    {'_id': 143,
#     'Anno': 2019,
#     'Data': '2019-05-23T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 1125047},
#    {'_id': 144,
#     'Anno': 2019,
#     'Data': '2019-05-24T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 1062691},
#    {'_id': 145,
#     'Anno': 2019,
#     'Data': '2019-05-25T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 1013079},
#    {'_id': 146,
#     'Anno': 2019,
#     'Data': '2019-05-26T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 988001},
#    {'_id': 147,
#     'Anno': 2019,
#     'Data': '2019-05-27T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 1106442},
#    {'_id': 148,
#     'Anno': 2019,
#     'Data': '2019-05-28T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 1104873},
#    {'_id': 149,
#     'Anno': 2019,
#     'Data': '2019-05-29T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 1121123},
#    {'_id': 150,
#     'Anno': 2019,
#     'Data': '2019-05-30T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 1066828},
#    {'_id': 151,
#     'Anno': 2019,
#     'Data': '2019-05-31T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 997774},
#    {'_id': 152,
#     'Anno': 2019,
#     'Data': '2019-06-01T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 897074},
#    {'_id': 153,
#     'Anno': 2019,
#     'Data': '2019-06-02T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 843253},
#    {'_id': 154,
#     'Anno': 2019,
#     'Data': '2019-06-03T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 922595},
#    {'_id': 155,
#     'Anno': 2019,
#     'Data': '2019-06-04T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 915045},
#    {'_id': 156,
#     'Anno': 2019,
#     'Data': '2019-06-05T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 924014},
#    {'_id': 157,
#     'Anno': 2019,
#     'Data': '2019-06-06T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 972052},
#    {'_id': 158,
#     'Anno': 2019,
#     'Data': '2019-06-07T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 939041},
#    {'_id': 159,
#     'Anno': 2019,
#     'Data': '2019-06-08T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 852711},
#    {'_id': 160,
#     'Anno': 2019,
#     'Data': '2019-06-09T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 825144},
#    {'_id': 161,
#     'Anno': 2019,
#     'Data': '2019-06-10T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 923925},
#    {'_id': 162,
#     'Anno': 2019,
#     'Data': '2019-06-11T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 932721},
#    {'_id': 163,
#     'Anno': 2019,
#     'Data': '2019-06-12T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 938679},
#    {'_id': 164,
#     'Anno': 2019,
#     'Data': '2019-06-13T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 926396},
#    {'_id': 165,
#     'Anno': 2019,
#     'Data': '2019-06-14T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 900921},
#    {'_id': 166,
#     'Anno': 2019,
#     'Data': '2019-06-15T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 819196},
#    {'_id': 167,
#     'Anno': 2019,
#     'Data': '2019-06-16T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 772529},
#    {'_id': 168,
#     'Anno': 2019,
#     'Data': '2019-06-17T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 852689},
#    {'_id': 169,
#     'Anno': 2019,
#     'Data': '2019-06-18T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 857092},
#    {'_id': 170,
#     'Anno': 2019,
#     'Data': '2019-06-19T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 851738},
#    {'_id': 171,
#     'Anno': 2019,
#     'Data': '2019-06-20T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 836583},
#    {'_id': 172,
#     'Anno': 2019,
#     'Data': '2019-06-21T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 862453},
#    {'_id': 173,
#     'Anno': 2019,
#     'Data': '2019-06-22T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 807489},
#    {'_id': 174,
#     'Anno': 2019,
#     'Data': '2019-06-23T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 752987},
#    {'_id': 175,
#     'Anno': 2019,
#     'Data': '2019-06-24T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 863409},
#    {'_id': 176,
#     'Anno': 2019,
#     'Data': '2019-06-25T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 845184},
#    {'_id': 177,
#     'Anno': 2019,
#     'Data': '2019-06-26T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 823953},
#    {'_id': 178,
#     'Anno': 2019,
#     'Data': '2019-06-27T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 774206},
#    {'_id': 179,
#     'Anno': 2019,
#     'Data': '2019-06-28T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 731553},
#    {'_id': 180,
#     'Anno': 2019,
#     'Data': '2019-06-29T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 665709},
#    {'_id': 181,
#     'Anno': 2019,
#     'Data': '2019-06-30T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 624928},
#    {'_id': 182,
#     'Anno': 2019,
#     'Data': '2019-07-01T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 761361},
#    {'_id': 183,
#     'Anno': 2019,
#     'Data': '2019-07-02T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 772221},
#    {'_id': 184,
#     'Anno': 2019,
#     'Data': '2019-07-03T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 781331},
#    {'_id': 185,
#     'Anno': 2019,
#     'Data': '2019-07-04T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 796556},
#    {'_id': 186,
#     'Anno': 2019,
#     'Data': '2019-07-05T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 759949},
#    {'_id': 187,
#     'Anno': 2019,
#     'Data': '2019-07-06T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 664321},
#    {'_id': 188,
#     'Anno': 2019,
#     'Data': '2019-07-07T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 628418},
#    {'_id': 189,
#     'Anno': 2019,
#     'Data': '2019-07-08T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 742516},
#    {'_id': 190,
#     'Anno': 2019,
#     'Data': '2019-07-09T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 780025},
#    {'_id': 191,
#     'Anno': 2019,
#     'Data': '2019-07-10T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 790549},
#    {'_id': 192,
#     'Anno': 2019,
#     'Data': '2019-07-11T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 823131},
#    {'_id': 193,
#     'Anno': 2019,
#     'Data': '2019-07-12T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 777523},
#    {'_id': 194,
#     'Anno': 2019,
#     'Data': '2019-07-13T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 684765},
#    {'_id': 195,
#     'Anno': 2019,
#     'Data': '2019-07-14T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 650839},
#    {'_id': 196,
#     'Anno': 2019,
#     'Data': '2019-07-15T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 812619},
#    {'_id': 197,
#     'Anno': 2019,
#     'Data': '2019-07-16T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 809744},
#    {'_id': 198,
#     'Anno': 2019,
#     'Data': '2019-07-17T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 771706},
#    {'_id': 199,
#     'Anno': 2019,
#     'Data': '2019-07-18T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 804223},
#    {'_id': 200,
#     'Anno': 2019,
#     'Data': '2019-07-19T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 758483},
#    {'_id': 201,
#     'Anno': 2019,
#     'Data': '2019-07-20T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 671069},
#    {'_id': 202,
#     'Anno': 2019,
#     'Data': '2019-07-21T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 642018},
#    {'_id': 203,
#     'Anno': 2019,
#     'Data': '2019-07-22T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 741202},
#    {'_id': 204,
#     'Anno': 2019,
#     'Data': '2019-07-23T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 728955},
#    {'_id': 205,
#     'Anno': 2019,
#     'Data': '2019-07-24T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 705076},
#    {'_id': 206,
#     'Anno': 2019,
#     'Data': '2019-07-25T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 682314},
#    {'_id': 207,
#     'Anno': 2019,
#     'Data': '2019-07-26T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 655552},
#    {'_id': 208,
#     'Anno': 2019,
#     'Data': '2019-07-27T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 611918},
#    {'_id': 209,
#     'Anno': 2019,
#     'Data': '2019-07-28T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 605670},
#    {'_id': 210,
#     'Anno': 2019,
#     'Data': '2019-07-29T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 690692},
#    {'_id': 211,
#     'Anno': 2019,
#     'Data': '2019-07-30T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 688695},
#    {'_id': 212,
#     'Anno': 2019,
#     'Data': '2019-07-31T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 698351},
#    {'_id': 213,
#     'Anno': 2019,
#     'Data': '2019-08-01T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 677071},
#    {'_id': 214,
#     'Anno': 2019,
#     'Data': '2019-08-02T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 645250},
#    {'_id': 215,
#     'Anno': 2019,
#     'Data': '2019-08-03T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 592731},
#    {'_id': 216,
#     'Anno': 2019,
#     'Data': '2019-08-04T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 547437},
#    {'_id': 217,
#     'Anno': 2019,
#     'Data': '2019-08-05T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 606778},
#    {'_id': 218,
#     'Anno': 2019,
#     'Data': '2019-08-06T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 623268},
#    {'_id': 219,
#     'Anno': 2019,
#     'Data': '2019-08-07T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 612769},
#    {'_id': 220,
#     'Anno': 2019,
#     'Data': '2019-08-08T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 600029},
#    {'_id': 221,
#     'Anno': 2019,
#     'Data': '2019-08-09T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 581880},
#    {'_id': 222,
#     'Anno': 2019,
#     'Data': '2019-08-10T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 507419},
#    {'_id': 223,
#     'Anno': 2019,
#     'Data': '2019-08-11T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 467094},
#    {'_id': 224,
#     'Anno': 2019,
#     'Data': '2019-08-12T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 517504},
#    {'_id': 225,
#     'Anno': 2019,
#     'Data': '2019-08-13T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 512515},
#    {'_id': 226,
#     'Anno': 2019,
#     'Data': '2019-08-14T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 509551},
#    {'_id': 227,
#     'Anno': 2019,
#     'Data': '2019-08-15T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 467820},
#    {'_id': 228,
#     'Anno': 2019,
#     'Data': '2019-08-16T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 495890},
#    {'_id': 229,
#     'Anno': 2019,
#     'Data': '2019-08-17T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 488095},
#    {'_id': 230,
#     'Anno': 2019,
#     'Data': '2019-08-18T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 474907},
#    {'_id': 231,
#     'Anno': 2019,
#     'Data': '2019-08-19T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 552030},
#    {'_id': 232,
#     'Anno': 2019,
#     'Data': '2019-08-20T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 562350},
#    {'_id': 233,
#     'Anno': 2019,
#     'Data': '2019-08-21T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 561939},
#    {'_id': 234,
#     'Anno': 2019,
#     'Data': '2019-08-22T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 595540},
#    {'_id': 235,
#     'Anno': 2019,
#     'Data': '2019-08-23T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 591333},
#    {'_id': 236,
#     'Anno': 2019,
#     'Data': '2019-08-24T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 551680},
#    {'_id': 237,
#     'Anno': 2019,
#     'Data': '2019-08-25T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 537151},
#    {'_id': 238,
#     'Anno': 2019,
#     'Data': '2019-08-26T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 645489},
#    {'_id': 239,
#     'Anno': 2019,
#     'Data': '2019-08-27T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 683550},
#    {'_id': 240,
#     'Anno': 2019,
#     'Data': '2019-08-28T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 729553},
#    {'_id': 241,
#     'Anno': 2019,
#     'Data': '2019-08-29T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 732348},
#    {'_id': 242,
#     'Anno': 2019,
#     'Data': '2019-08-30T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 707176},
#    {'_id': 243,
#     'Anno': 2019,
#     'Data': '2019-08-31T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 665625},
#    {'_id': 244,
#     'Anno': 2019,
#     'Data': '2019-09-01T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 650825},
#    {'_id': 245,
#     'Anno': 2019,
#     'Data': '2019-09-02T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 772214},
#    {'_id': 246,
#     'Anno': 2019,
#     'Data': '2019-09-03T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 817210},
#    {'_id': 247,
#     'Anno': 2019,
#     'Data': '2019-09-04T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 835441},
#    {'_id': 248,
#     'Anno': 2019,
#     'Data': '2019-09-05T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 838132},
#    {'_id': 249,
#     'Anno': 2019,
#     'Data': '2019-09-06T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 862476},
#    {'_id': 250,
#     'Anno': 2019,
#     'Data': '2019-09-07T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 797175},
#    {'_id': 251,
#     'Anno': 2019,
#     'Data': '2019-09-08T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 807908},
#    {'_id': 252,
#     'Anno': 2019,
#     'Data': '2019-09-09T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 934727},
#    {'_id': 253,
#     'Anno': 2019,
#     'Data': '2019-09-10T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 923002},
#    {'_id': 254,
#     'Anno': 2019,
#     'Data': '2019-09-11T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 936032},
#    {'_id': 255,
#     'Anno': 2019,
#     'Data': '2019-09-12T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 920913},
#    {'_id': 256,
#     'Anno': 2019,
#     'Data': '2019-09-13T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 891867},
#    {'_id': 257,
#     'Anno': 2019,
#     'Data': '2019-09-14T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 816442},
#    {'_id': 258,
#     'Anno': 2019,
#     'Data': '2019-09-15T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 771639},
#    {'_id': 259,
#     'Anno': 2019,
#     'Data': '2019-09-16T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 876643},
#    {'_id': 260,
#     'Anno': 2019,
#     'Data': '2019-09-17T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 895844},
#    {'_id': 261,
#     'Anno': 2019,
#     'Data': '2019-09-18T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 898019},
#    {'_id': 262,
#     'Anno': 2019,
#     'Data': '2019-09-19T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 937759},
#    {'_id': 263,
#     'Anno': 2019,
#     'Data': '2019-09-20T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 933082},
#    {'_id': 264,
#     'Anno': 2019,
#     'Data': '2019-09-21T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 862868},
#    {'_id': 265,
#     'Anno': 2019,
#     'Data': '2019-09-22T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 877811},
#    {'_id': 266,
#     'Anno': 2019,
#     'Data': '2019-09-23T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 1010573},
#    {'_id': 267,
#     'Anno': 2019,
#     'Data': '2019-09-24T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 990300},
#    {'_id': 268,
#     'Anno': 2019,
#     'Data': '2019-09-25T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 988158},
#    {'_id': 269,
#     'Anno': 2019,
#     'Data': '2019-09-26T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 980682},
#    {'_id': 270,
#     'Anno': 2019,
#     'Data': '2019-09-27T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 948710},
#    {'_id': 271,
#     'Anno': 2019,
#     'Data': '2019-09-28T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 877545},
#    {'_id': 272,
#     'Anno': 2019,
#     'Data': '2019-09-29T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 860702},
#    {'_id': 273,
#     'Anno': 2019,
#     'Data': '2019-09-30T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 937963},
#    {'_id': 274,
#     'Anno': 2019,
#     'Data': '2019-10-01T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 941203},
#    {'_id': 275,
#     'Anno': 2019,
#     'Data': '2019-10-02T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 951156},
#    {'_id': 276,
#     'Anno': 2019,
#     'Data': '2019-10-03T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 982627},
#    {'_id': 277,
#     'Anno': 2019,
#     'Data': '2019-10-04T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 1003028},
#    {'_id': 278,
#     'Anno': 2019,
#     'Data': '2019-10-05T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 949909},
#    {'_id': 279,
#     'Anno': 2019,
#     'Data': '2019-10-06T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 969067},
#    {'_id': 280,
#     'Anno': 2019,
#     'Data': '2019-10-07T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 1058309},
#    {'_id': 281,
#     'Anno': 2019,
#     'Data': '2019-10-08T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 1111190},
#    {'_id': 282,
#     'Anno': 2019,
#     'Data': '2019-10-09T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 1211418},
#    {'_id': 283,
#     'Anno': 2019,
#     'Data': '2019-10-10T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 1230867},
#    {'_id': 284,
#     'Anno': 2019,
#     'Data': '2019-10-11T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 1250576},
#    {'_id': 285,
#     'Anno': 2019,
#     'Data': '2019-10-12T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 1162440},
#    {'_id': 286,
#     'Anno': 2019,
#     'Data': '2019-10-13T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 1199847},
#    {'_id': 287,
#     'Anno': 2019,
#     'Data': '2019-10-14T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 1554350},
#    {'_id': 288,
#     'Anno': 2019,
#     'Data': '2019-10-15T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 2522652},
#    {'_id': 289,
#     'Anno': 2019,
#     'Data': '2019-10-16T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 2817085},
#    {'_id': 290,
#     'Anno': 2019,
#     'Data': '2019-10-17T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 2706008},
#    {'_id': 291,
#     'Anno': 2019,
#     'Data': '2019-10-18T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 2697402},
#    {'_id': 292,
#     'Anno': 2019,
#     'Data': '2019-10-19T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 2669294},
#    {'_id': 293,
#     'Anno': 2019,
#     'Data': '2019-10-20T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 2493748},
#    {'_id': 294,
#     'Anno': 2019,
#     'Data': '2019-10-21T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 2725044},
#    {'_id': 295,
#     'Anno': 2019,
#     'Data': '2019-10-22T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 2382271},
#    {'_id': 296,
#     'Anno': 2019,
#     'Data': '2019-10-23T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 2289742},
#    {'_id': 297,
#     'Anno': 2019,
#     'Data': '2019-10-24T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 2666632},
#    {'_id': 298,
#     'Anno': 2019,
#     'Data': '2019-10-25T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 2503955},
#    {'_id': 299,
#     'Anno': 2019,
#     'Data': '2019-10-26T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 2234730},
#    {'_id': 300,
#     'Anno': 2019,
#     'Data': '2019-10-27T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 2329784},
#    {'_id': 301,
#     'Anno': 2019,
#     'Data': '2019-10-28T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 2521036},
#    {'_id': 302,
#     'Anno': 2019,
#     'Data': '2019-10-29T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 2744566},
#    {'_id': 303,
#     'Anno': 2019,
#     'Data': '2019-10-30T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 3249615},
#    {'_id': 304,
#     'Anno': 2019,
#     'Data': '2019-10-31T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 3703340},
#    {'_id': 305,
#     'Anno': 2019,
#     'Data': '2019-11-01T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 3520611},
#    {'_id': 306,
#     'Anno': 2019,
#     'Data': '2019-11-02T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 3799532},
#    {'_id': 307,
#     'Anno': 2019,
#     'Data': '2019-11-03T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 4057186},
#    {'_id': 308,
#     'Anno': 2019,
#     'Data': '2019-11-04T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 4250253},
#    {'_id': 309,
#     'Anno': 2019,
#     'Data': '2019-11-05T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 4046886},
#    {'_id': 310,
#     'Anno': 2019,
#     'Data': '2019-11-06T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 4693474},
#    {'_id': 311,
#     'Anno': 2019,
#     'Data': '2019-11-07T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 5076165},
#    {'_id': 312,
#     'Anno': 2019,
#     'Data': '2019-11-08T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 5107481},
#    {'_id': 313,
#     'Anno': 2019,
#     'Data': '2019-11-09T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 4787683},
#    {'_id': 314,
#     'Anno': 2019,
#     'Data': '2019-11-10T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 4869735},
#    {'_id': 315,
#     'Anno': 2019,
#     'Data': '2019-11-11T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 5695337},
#    {'_id': 316,
#     'Anno': 2019,
#     'Data': '2019-11-12T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 5768489},
#    {'_id': 317,
#     'Anno': 2019,
#     'Data': '2019-11-13T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 5617686},
#    {'_id': 318,
#     'Anno': 2019,
#     'Data': '2019-11-14T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 6176466},
#    {'_id': 319,
#     'Anno': 2019,
#     'Data': '2019-11-15T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 6196103},
#    {'_id': 320,
#     'Anno': 2019,
#     'Data': '2019-11-16T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 5613950},
#    {'_id': 321,
#     'Anno': 2019,
#     'Data': '2019-11-17T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 5823348},
#    {'_id': 322,
#     'Anno': 2019,
#     'Data': '2019-11-18T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 6346583},
#    {'_id': 323,
#     'Anno': 2019,
#     'Data': '2019-11-19T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 6323181},
#    {'_id': 324,
#     'Anno': 2019,
#     'Data': '2019-11-20T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 5762609},
#    {'_id': 325,
#     'Anno': 2019,
#     'Data': '2019-11-21T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 5581458},
#    {'_id': 326,
#     'Anno': 2019,
#     'Data': '2019-11-22T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 5618678},
#    {'_id': 327,
#     'Anno': 2019,
#     'Data': '2019-11-23T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 5171138},
#    {'_id': 328,
#     'Anno': 2019,
#     'Data': '2019-11-24T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 4908784},
#    {'_id': 329,
#     'Anno': 2019,
#     'Data': '2019-11-25T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 4719433},
#    {'_id': 330,
#     'Anno': 2019,
#     'Data': '2019-11-26T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 5021472},
#    {'_id': 331,
#     'Anno': 2019,
#     'Data': '2019-11-27T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 5322911},
#    {'_id': 332,
#     'Anno': 2019,
#     'Data': '2019-11-28T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 5386867},
#    {'_id': 333,
#     'Anno': 2019,
#     'Data': '2019-11-29T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 5883571},
#    {'_id': 334,
#     'Anno': 2019,
#     'Data': '2019-11-30T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 6036081},
#    {'_id': 335,
#     'Anno': 2019,
#     'Data': '2019-12-01T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 5406442},
#    {'_id': 336,
#     'Anno': 2019,
#     'Data': '2019-12-02T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 5746423},
#    {'_id': 337,
#     'Anno': 2019,
#     'Data': '2019-12-03T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 5715261},
#    {'_id': 338,
#     'Anno': 2019,
#     'Data': '2019-12-04T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 6146303},
#    {'_id': 339,
#     'Anno': 2019,
#     'Data': '2019-12-05T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 6475964},
#    {'_id': 340,
#     'Anno': 2019,
#     'Data': '2019-12-06T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 6569760},
#    {'_id': 341,
#     'Anno': 2019,
#     'Data': '2019-12-07T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 5850979},
#    {'_id': 342,
#     'Anno': 2019,
#     'Data': '2019-12-08T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 5730070},
#    {'_id': 343,
#     'Anno': 2019,
#     'Data': '2019-12-09T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 6078788},
#    {'_id': 344,
#     'Anno': 2019,
#     'Data': '2019-12-10T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 5757805},
#    {'_id': 345,
#     'Anno': 2019,
#     'Data': '2019-12-11T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 6519509},
#    {'_id': 346,
#     'Anno': 2019,
#     'Data': '2019-12-12T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 7013979},
#    {'_id': 347,
#     'Anno': 2019,
#     'Data': '2019-12-13T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 7419069},
#    {'_id': 348,
#     'Anno': 2019,
#     'Data': '2019-12-14T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 6503819},
#    {'_id': 349,
#     'Anno': 2019,
#     'Data': '2019-12-15T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 6299755},
#    {'_id': 350,
#     'Anno': 2019,
#     'Data': '2019-12-16T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 6415606},
#    {'_id': 351,
#     'Anno': 2019,
#     'Data': '2019-12-17T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 6057176},
#    {'_id': 352,
#     'Anno': 2019,
#     'Data': '2019-12-18T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 5689911},
#    {'_id': 353,
#     'Anno': 2019,
#     'Data': '2019-12-19T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 5273789},
#    {'_id': 354,
#     'Anno': 2019,
#     'Data': '2019-12-20T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 5375625},
#    {'_id': 355,
#     'Anno': 2019,
#     'Data': '2019-12-21T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 4903495},
#    {'_id': 356,
#     'Anno': 2019,
#     'Data': '2019-12-22T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 4855112},
#    {'_id': 357,
#     'Anno': 2019,
#     'Data': '2019-12-23T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 5109002},
#    {'_id': 358,
#     'Anno': 2019,
#     'Data': '2019-12-24T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 5131281},
#    {'_id': 359,
#     'Anno': 2019,
#     'Data': '2019-12-25T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 4793405},
#    {'_id': 360,
#     'Anno': 2019,
#     'Data': '2019-12-26T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 5306387},
#    {'_id': 361,
#     'Anno': 2019,
#     'Data': '2019-12-27T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 5863923},
#    {'_id': 362,
#     'Anno': 2019,
#     'Data': '2019-12-28T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 5750649},
#    {'_id': 363,
#     'Anno': 2019,
#     'Data': '2019-12-29T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 5998544},
#    {'_id': 364,
#     'Anno': 2019,
#     'Data': '2019-12-30T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 6570685},
#    {'_id': 365,
#     'Anno': 2019,
#     'Data': '2019-12-31T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 6666107},
#    {'_id': 366,
#     'Anno': 2020,
#     'Data': '2020-01-01T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 6219004},
#    {'_id': 367,
#     'Anno': 2020,
#     'Data': '2020-01-02T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 6738310},
#    {'_id': 368,
#     'Anno': 2020,
#     'Data': '2020-01-03T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 6666271},
#    {'_id': 369,
#     'Anno': 2020,
#     'Data': '2020-01-04T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 6312640},
#    {'_id': 370,
#     'Anno': 2020,
#     'Data': '2020-01-05T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 6121271},
#    {'_id': 371,
#     'Anno': 2020,
#     'Data': '2020-01-06T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 7127708},
#    {'_id': 372,
#     'Anno': 2020,
#     'Data': '2020-01-07T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 8031925},
#    {'_id': 373,
#     'Anno': 2020,
#     'Data': '2020-01-08T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 8199636},
#    {'_id': 374,
#     'Anno': 2020,
#     'Data': '2020-01-09T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 7809163},
#    {'_id': 375,
#     'Anno': 2020,
#     'Data': '2020-01-10T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 7131918},
#    {'_id': 376,
#     'Anno': 2020,
#     'Data': '2020-01-11T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 6624310},
#    {'_id': 377,
#     'Anno': 2020,
#     'Data': '2020-01-12T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 6634034},
#    {'_id': 378,
#     'Anno': 2020,
#     'Data': '2020-01-13T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 7360299},
#    {'_id': 379,
#     'Anno': 2020,
#     'Data': '2020-01-14T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 7326389},
#    {'_id': 380,
#     'Anno': 2020,
#     'Data': '2020-01-15T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 7050102},
#    {'_id': 381,
#     'Anno': 2020,
#     'Data': '2020-01-16T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 6820501},
#    {'_id': 382,
#     'Anno': 2020,
#     'Data': '2020-01-17T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 6641520},
#    {'_id': 383,
#     'Anno': 2020,
#     'Data': '2020-01-18T00:00:00',
#     'Giorno': 'Sabato',
# ...
#     'Anno': 2020,
#     'Data': '2020-08-27T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 659844},
#    {'_id': 606,
#     'Anno': 2020,
#     'Data': '2020-08-28T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 657281},
#    {'_id': 607,
#     'Anno': 2020,
#     'Data': '2020-08-29T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 626213},
#    {'_id': 608,
#     'Anno': 2020,
#     'Data': '2020-08-30T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 670958},
#    {'_id': 609,
#     'Anno': 2020,
#     'Data': '2020-08-31T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 804210},
#    {'_id': 610,
#     'Anno': 2020,
#     'Data': '2020-09-01T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 810899},
#    {'_id': 611,
#     'Anno': 2020,
#     'Data': '2020-09-02T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 846179},
#    {'_id': 612,
#     'Anno': 2020,
#     'Data': '2020-09-03T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 800892},
#    {'_id': 613,
#     'Anno': 2020,
#     'Data': '2020-09-04T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 804910},
#    {'_id': 614,
#     'Anno': 2020,
#     'Data': '2020-09-05T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 722847},
#    {'_id': 615,
#     'Anno': 2020,
#     'Data': '2020-09-06T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 718042},
#    {'_id': 616,
#     'Anno': 2020,
#     'Data': '2020-09-07T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 857313},
#    {'_id': 617,
#     'Anno': 2020,
#     'Data': '2020-09-08T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 853467},
#    {'_id': 618,
#     'Anno': 2020,
#     'Data': '2020-09-09T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 859051},
#    {'_id': 619,
#     'Anno': 2020,
#     'Data': '2020-09-10T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 845387},
#    {'_id': 620,
#     'Anno': 2020,
#     'Data': '2020-09-11T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 845128},
#    {'_id': 621,
#     'Anno': 2020,
#     'Data': '2020-09-12T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 734882},
#    {'_id': 622,
#     'Anno': 2020,
#     'Data': '2020-09-13T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 733197},
#    {'_id': 623,
#     'Anno': 2020,
#     'Data': '2020-09-14T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 819739},
#    {'_id': 624,
#     'Anno': 2020,
#     'Data': '2020-09-15T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 874579},
#    {'_id': 625,
#     'Anno': 2020,
#     'Data': '2020-09-16T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 831076},
#    {'_id': 626,
#     'Anno': 2020,
#     'Data': '2020-09-17T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 836003},
#    {'_id': 627,
#     'Anno': 2020,
#     'Data': '2020-09-18T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 820843},
#    {'_id': 628,
#     'Anno': 2020,
#     'Data': '2020-09-19T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 772063},
#    {'_id': 629,
#     'Anno': 2020,
#     'Data': '2020-09-20T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 769390},
#    {'_id': 630,
#     'Anno': 2020,
#     'Data': '2020-09-21T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 864287},
#    {'_id': 631,
#     'Anno': 2020,
#     'Data': '2020-09-22T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 911688},
#    {'_id': 632,
#     'Anno': 2020,
#     'Data': '2020-09-23T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 913052},
#    {'_id': 633,
#     'Anno': 2020,
#     'Data': '2020-09-24T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 907875},
#    {'_id': 634,
#     'Anno': 2020,
#     'Data': '2020-09-25T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 963587},
#    {'_id': 635,
#     'Anno': 2020,
#     'Data': '2020-09-26T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 939411},
#    {'_id': 636,
#     'Anno': 2020,
#     'Data': '2020-09-27T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 987654},
#    {'_id': 637,
#     'Anno': 2020,
#     'Data': '2020-09-28T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 1079594},
#    {'_id': 638,
#     'Anno': 2020,
#     'Data': '2020-09-29T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 1068471},
#    {'_id': 639,
#     'Anno': 2020,
#     'Data': '2020-09-30T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 1028625},
#    {'_id': 640,
#     'Anno': 2020,
#     'Data': '2020-10-01T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 1051062},
#    {'_id': 641,
#     'Anno': 2020,
#     'Data': '2020-10-02T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 1117960},
#    {'_id': 642,
#     'Anno': 2020,
#     'Data': '2020-10-03T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 1020040},
#    {'_id': 643,
#     'Anno': 2020,
#     'Data': '2020-10-04T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 1040903},
#    {'_id': 644,
#     'Anno': 2020,
#     'Data': '2020-10-05T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 1231822},
#    {'_id': 645,
#     'Anno': 2020,
#     'Data': '2020-10-06T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 1279897},
#    {'_id': 646,
#     'Anno': 2020,
#     'Data': '2020-10-07T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 1270257},
#    {'_id': 647,
#     'Anno': 2020,
#     'Data': '2020-10-08T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 1329884},
#    {'_id': 648,
#     'Anno': 2020,
#     'Data': '2020-10-09T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 1386091},
#    {'_id': 649,
#     'Anno': 2020,
#     'Data': '2020-10-10T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 1300865},
#    {'_id': 650,
#     'Anno': 2020,
#     'Data': '2020-10-11T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 1572231},
#    {'_id': 651,
#     'Anno': 2020,
#     'Data': '2020-10-12T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 2073720},
#    {'_id': 652,
#     'Anno': 2020,
#     'Data': '2020-10-13T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 2624624},
#    {'_id': 653,
#     'Anno': 2020,
#     'Data': '2020-10-14T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 3223356},
#    {'_id': 654,
#     'Anno': 2020,
#     'Data': '2020-10-15T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 4317319},
#    {'_id': 655,
#     'Anno': 2020,
#     'Data': '2020-10-16T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 4129874},
#    {'_id': 656,
#     'Anno': 2020,
#     'Data': '2020-10-17T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 3824076},
#    {'_id': 657,
#     'Anno': 2020,
#     'Data': '2020-10-18T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 3753099},
#    {'_id': 658,
#     'Anno': 2020,
#     'Data': '2020-10-19T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 3992700},
#    {'_id': 659,
#     'Anno': 2020,
#     'Data': '2020-10-20T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 4091120},
#    {'_id': 660,
#     'Anno': 2020,
#     'Data': '2020-10-21T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 3949283},
#    {'_id': 661,
#     'Anno': 2020,
#     'Data': '2020-10-22T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 3954239},
#    {'_id': 662,
#     'Anno': 2020,
#     'Data': '2020-10-23T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 3956606},
#    {'_id': 663,
#     'Anno': 2020,
#     'Data': '2020-10-24T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 3397207},
#    {'_id': 664,
#     'Anno': 2020,
#     'Data': '2020-10-25T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 3345846},
#    {'_id': 665,
#     'Anno': 2020,
#     'Data': '2020-10-26T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 4030471},
#    {'_id': 666,
#     'Anno': 2020,
#     'Data': '2020-10-27T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 4272977},
#    {'_id': 667,
#     'Anno': 2020,
#     'Data': '2020-10-28T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 4041803},
#    {'_id': 668,
#     'Anno': 2020,
#     'Data': '2020-10-29T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 4076909},
#    {'_id': 669,
#     'Anno': 2020,
#     'Data': '2020-10-30T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 3848180},
#    {'_id': 670,
#     'Anno': 2020,
#     'Data': '2020-10-31T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 3737928},
#    {'_id': 671,
#     'Anno': 2020,
#     'Data': '2020-11-01T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 3920894},
#    {'_id': 672,
#     'Anno': 2020,
#     'Data': '2020-11-02T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 3995512},
#    {'_id': 673,
#     'Anno': 2020,
#     'Data': '2020-11-03T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 3706490},
#    {'_id': 674,
#     'Anno': 2020,
#     'Data': '2020-11-04T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 3486682},
#    {'_id': 675,
#     'Anno': 2020,
#     'Data': '2020-11-05T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 3462851},
#    {'_id': 676,
#     'Anno': 2020,
#     'Data': '2020-11-06T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 3348238},
#    {'_id': 677,
#     'Anno': 2020,
#     'Data': '2020-11-07T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 3576993},
#    {'_id': 678,
#     'Anno': 2020,
#     'Data': '2020-11-08T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 3495862},
#    {'_id': 679,
#     'Anno': 2020,
#     'Data': '2020-11-09T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 3697986},
#    {'_id': 680,
#     'Anno': 2020,
#     'Data': '2020-11-10T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 3926543},
#    {'_id': 681,
#     'Anno': 2020,
#     'Data': '2020-11-11T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 4493256},
#    {'_id': 682,
#     'Anno': 2020,
#     'Data': '2020-11-12T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 4293982},
#    {'_id': 683,
#     'Anno': 2020,
#     'Data': '2020-11-13T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 4229361},
#    {'_id': 684,
#     'Anno': 2020,
#     'Data': '2020-11-14T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 3986227},
#    {'_id': 685,
#     'Anno': 2020,
#     'Data': '2020-11-15T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 3904128},
#    {'_id': 686,
#     'Anno': 2020,
#     'Data': '2020-11-16T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 4431635},
#    {'_id': 687,
#     'Anno': 2020,
#     'Data': '2020-11-17T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 4854732},
#    {'_id': 688,
#     'Anno': 2020,
#     'Data': '2020-11-18T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 5442889},
#    {'_id': 689,
#     'Anno': 2020,
#     'Data': '2020-11-19T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 5584830},
#    {'_id': 690,
#     'Anno': 2020,
#     'Data': '2020-11-20T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 5189506},
#    {'_id': 691,
#     'Anno': 2020,
#     'Data': '2020-11-21T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 5307712},
#    {'_id': 692,
#     'Anno': 2020,
#     'Data': '2020-11-22T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 5552148},
#    {'_id': 693,
#     'Anno': 2020,
#     'Data': '2020-11-23T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 6073092},
#    {'_id': 694,
#     'Anno': 2020,
#     'Data': '2020-11-24T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 6012794},
#    {'_id': 695,
#     'Anno': 2020,
#     'Data': '2020-11-25T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 6178885},
#    {'_id': 696,
#     'Anno': 2020,
#     'Data': '2020-11-26T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 6389964},
#    {'_id': 697,
#     'Anno': 2020,
#     'Data': '2020-11-27T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 6503961},
#    {'_id': 698,
#     'Anno': 2020,
#     'Data': '2020-11-28T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 5837868},
#    {'_id': 699,
#     'Anno': 2020,
#     'Data': '2020-11-29T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 5620498},
#    {'_id': 700,
#     'Anno': 2020,
#     'Data': '2020-11-30T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 6462569},
#    {'_id': 701,
#     'Anno': 2020,
#     'Data': '2020-12-01T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 6680800},
#    {'_id': 702,
#     'Anno': 2020,
#     'Data': '2020-12-02T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 7536553},
#    {'_id': 703,
#     'Anno': 2020,
#     'Data': '2020-12-03T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 7612968},
#    {'_id': 704,
#     'Anno': 2020,
#     'Data': '2020-12-04T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 7710918},
#    {'_id': 705,
#     'Anno': 2020,
#     'Data': '2020-12-05T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 7221079},
#    {'_id': 706,
#     'Anno': 2020,
#     'Data': '2020-12-06T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 6951802},
#    {'_id': 707,
#     'Anno': 2020,
#     'Data': '2020-12-07T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 7185733},
#    {'_id': 708,
#     'Anno': 2020,
#     'Data': '2020-12-08T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 6986054},
#    {'_id': 709,
#     'Anno': 2020,
#     'Data': '2020-12-09T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 7027492},
#    {'_id': 710,
#     'Anno': 2020,
#     'Data': '2020-12-10T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 6783921},
#    {'_id': 711,
#     'Anno': 2020,
#     'Data': '2020-12-11T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 7095520},
#    {'_id': 712,
#     'Anno': 2020,
#     'Data': '2020-12-12T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 6576987},
#    {'_id': 713,
#     'Anno': 2020,
#     'Data': '2020-12-13T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 6864534},
#    {'_id': 714,
#     'Anno': 2020,
#     'Data': '2020-12-14T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 7387022},
#    {'_id': 715,
#     'Anno': 2020,
#     'Data': '2020-12-15T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 7066528},
#    {'_id': 716,
#     'Anno': 2020,
#     'Data': '2020-12-16T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 6657930},
#    {'_id': 717,
#     'Anno': 2020,
#     'Data': '2020-12-17T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 6319199},
#    {'_id': 718,
#     'Anno': 2020,
#     'Data': '2020-12-18T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 6204364},
#    {'_id': 719,
#     'Anno': 2020,
#     'Data': '2020-12-19T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 5640294},
#    {'_id': 720,
#     'Anno': 2020,
#     'Data': '2020-12-20T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 5745426},
#    {'_id': 721,
#     'Anno': 2020,
#     'Data': '2020-12-21T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 6015537},
#    {'_id': 722,
#     'Anno': 2020,
#     'Data': '2020-12-22T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 5805929},
#    {'_id': 723,
#     'Anno': 2020,
#     'Data': '2020-12-23T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 5506734},
#    {'_id': 724,
#     'Anno': 2020,
#     'Data': '2020-12-24T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 5470777},
#    {'_id': 725,
#     'Anno': 2020,
#     'Data': '2020-12-25T00:00:00',
#     'Giorno': 'Venerdi',
#     'Totale (Smc)': 5732196},
#    {'_id': 726,
#     'Anno': 2020,
#     'Data': '2020-12-26T00:00:00',
#     'Giorno': 'Sabato',
#     'Totale (Smc)': 5967677},
#    {'_id': 727,
#     'Anno': 2020,
#     'Data': '2020-12-27T00:00:00',
#     'Giorno': 'Domenica',
#     'Totale (Smc)': 6714208},
#    {'_id': 728,
#     'Anno': 2020,
#     'Data': '2020-12-28T00:00:00',
#     'Giorno': 'Lunedi',
#     'Totale (Smc)': 7667257},
#    {'_id': 729,
#     'Anno': 2020,
#     'Data': '2020-12-29T00:00:00',
#     'Giorno': 'Martedi',
#     'Totale (Smc)': 7897478},
#    {'_id': 730,
#     'Anno': 2020,
#     'Data': '2020-12-30T00:00:00',
#     'Giorno': 'Mercoledi',
#     'Totale (Smc)': 7719484},
#    {'_id': 731,
#     'Anno': 2020,
#     'Data': '2020-12-31T00:00:00',
#     'Giorno': 'Giovedi',
#     'Totale (Smc)': 7773887}],
#   'limit': 1000,
#   '_links': {'start': '/api/3/action/datastore_search?limit=1000&resource_id=dbd7417a-41e8-4097-a1c4-67094983bab1',
#    'next': '/api/3/action/datastore_search?offset=1000&limit=1000&resource_id=dbd7417a-41e8-4097-a1c4-67094983bab1'},
#   'total': 731}}

# %% [markdown]
# We can verify that this JSON object is in fact interpreted by Python as a dictionary:

# %%
type(r.json())
# Out:
# dict

# %% [markdown]
# And, since it is a dictionary, it can be accessed as one by specifying its keys via the [ ] operator:

# %%
r.json()['result']['fields']
# Out:
# [{'type': 'int', 'id': '_id'},
#  {'info': {'notes': '', 'type_override': '', 'label': ''},
#   'type': 'numeric',
#   'id': 'Anno'},
#  {'info': {'notes': '', 'type_override': '', 'label': ''},
#   'type': 'timestamp',
#   'id': 'Data'},
#  {'info': {'notes': '', 'type_override': '', 'label': ''},
#   'type': 'text',
#   'id': 'Giorno'},
#  {'info': {'notes': '', 'type_override': 'numeric', 'label': ''},
#   'type': 'numeric',
#   'id': 'Totale (Smc)'}]

# %% [markdown]
# In the cell above we sliced the dictionary until we reached the `fields` key, which is itself a list of dictionaries. Therefore, we can cycle through each dictionary in this list and print the `id` keys, whose values contain the column names of the data that we retrieved using the API: *

# %%
for el in r.json()['result']['fields']: 
    print(el['id'], el['type'])
# Out:
# _id int
# Anno numeric
# Data timestamp
# Giorno text
# Totale (Smc) numeric

# %% [markdown]
# Luckily, we don't need to loop through nested dictionaries to get the data in a useful format. If we slice the JSON object at the `records` key, we can see that it is composed of a list of dictionaries (as many as there are rows in the original dataset), each containing a set of key-value pairs (one for each column in the dataset).

# %%
r.json()['result']['records'][0:3]
# Out:
# [{'_id': 1,
#   'Anno': 2019,
#   'Data': '2019-01-01T00:00:00',
#   'Giorno': 'Martedi',
#   'Totale (Smc)': 6603230},
#  {'_id': 2,
#   'Anno': 2019,
#   'Data': '2019-01-02T00:00:00',
#   'Giorno': 'Mercoledi',
#   'Totale (Smc)': 6579016},
#  {'_id': 3,
#   'Anno': 2019,
#   'Data': '2019-01-03T00:00:00',
#   'Giorno': 'Giovedi',
#   'Totale (Smc)': 7115704}]

# %%
len(r.json()['result']['records'])
# Out:
# 731

# %% [markdown]
# Thanks to `pandas`, we can build a DataFrame using its `from_dict()` function:

# %%
df = pd.DataFrame.from_dict(r.json()['result']['records'])
df
# Out:
#      _id  Anno                 Data     Giorno  Totale (Smc)
# 0      1  2019  2019-01-01T00:00:00    Martedi     6603230.0
# 1      2  2019  2019-01-02T00:00:00  Mercoledi     6579016.0
# 2      3  2019  2019-01-03T00:00:00    Giovedi     7115704.0
# 3      4  2019  2019-01-04T00:00:00    Venerdi     7650062.0
# 4      5  2019  2019-01-05T00:00:00     Sabato     7471068.0
# ..   ...   ...                  ...        ...           ...
# 726  727  2020  2020-12-27T00:00:00   Domenica     6714208.0
# 727  728  2020  2020-12-28T00:00:00     Lunedi     7667257.0
# 728  729  2020  2020-12-29T00:00:00    Martedi     7897478.0
# 729  730  2020  2020-12-30T00:00:00  Mercoledi     7719484.0
# 730  731  2020  2020-12-31T00:00:00    Giovedi     7773887.0
#
# [731 rows x 5 columns]

# %% [markdown]
# Let's quickly convert the `Data` variable to a datetime type and plot the time series using `seaborn`:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   _id           731 non-null    int64
#  1   Anno          731 non-null    int64
#  2   Data          731 non-null    object
#  3   Giorno        731 non-null    object
#  4   Totale (Smc)  731 non-null    float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 28.7+ KB

# %%
df['Data'] = pd.to_datetime(df['Data'], format="%Y-%m-%dT%H:%M:%S")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   _id           731 non-null    int64
#  1   Anno          731 non-null    int64
#  2   Data          731 non-null    datetime64[ns]
#  3   Giorno        731 non-null    object
#  4   Totale (Smc)  731 non-null    float64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(1)
# memory usage: 28.7+ KB

# %%
df.head()
# Out:
#    _id  Anno       Data     Giorno  Totale (Smc)
# 0    1  2019 2019-01-01    Martedi     6603230.0
# 1    2  2019 2019-01-02  Mercoledi     6579016.0
# 2    3  2019 2019-01-03    Giovedi     7115704.0
# 3    4  2019 2019-01-04    Venerdi     7650062.0
# 4    5  2019 2019-01-05     Sabato     7471068.0

# %%
sns.set(rc={'figure.figsize':(15, 7)})   # change the figure size
sns.lineplot(x="Data", y="Totale (Smc)", data=df)
plt.show()

# %% [markdown]
# #### More public APIs

# %% [markdown]
# At [this web page](https://mixedanalytics.com/blog/list-actually-free-open-no-auth-needed-apis/), you can find a long list of public APIs, meaning you can use them without the need to sign-up, create an account or authenticate to the service in order to access the unterlying data. To keep things nice and simple and allow you to practice more with APIs, let's look at that list and, for instance let's try the [Binance API](https://binance-docs.github.io/apidocs/spot/en/#introduction) example, which shows the endpoint to get some statistics on the [24hr Ticker Price Change](https://binance-docs.github.io/apidocs/spot/en/#24hr-ticker-price-change-statistics):

# %%
url_binance = 'https://api2.binance.com/api/v3/ticker/24hr'
bnc = requests.get(url_binance)

# %%
bnc.status_code
# Out:
# 200

# %%
bnc.json()[0:3]
# Out:
# [{'symbol': 'ETHBTC',
#   'priceChange': '-0.00014000',
#   'priceChangePercent': '-0.397',
#   'weightedAvgPrice': '0.03526913',
#   'prevClosePrice': '0.03529000',
#   'lastPrice': '0.03515000',
#   'lastQty': '0.00510000',
#   'bidPrice': '0.03514000',
#   'bidQty': '41.17410000',
#   'askPrice': '0.03515000',
#   'askQty': '14.94800000',
#   'openPrice': '0.03529000',
#   'highPrice': '0.03561000',
#   'lowPrice': '0.03476000',
#   'volume': '19375.91280000',
#   'quoteVolume': '683.37154029',
#   'openTime': 1761157606796,
#   'closeTime': 1761244006796,
#   'firstId': 514223484,
#   'lastId': 514304042,
#   'count': 80559},
#  {'symbol': 'LTCBTC',
#   'priceChange': '-0.00002100',
#   'priceChangePercent': '-2.405',
#   'weightedAvgPrice': '0.00085329',
#   'prevClosePrice': '0.00087300',
#   'lastPrice': '0.00085200',
#   'lastQty': '2.17500000',
#   'bidPrice': '0.00085100',
#   'bidQty': '248.88300000',
#   'askPrice': '0.00085200',
#   'askQty': '291.48400000',
#   'openPrice': '0.00087300',
#   'highPrice': '0.00087800',
#   'lowPrice': '0.00084100',
#   'volume': '8893.06300000',
#   'quoteVolume': '7.58834451',
#   'openTime': 1761157601204,
#   'closeTime': 1761244001204,
#   'firstId': 106089638,
#   'lastId': 106094428,
#   'count': 4791},
#  {'symbol': 'BNBBTC',
#   'priceChange': '0.00025900',
#   'priceChangePercent': '2.617',
#   'weightedAvgPrice': '0.01009484',
#   'prevClosePrice': '0.00989700',
#   'lastPrice': '0.01015500',
#   'lastQty': '0.01900000',
#   'bidPrice': '0.01015400',
#   'bidQty': '3.82800000',
#   'askPrice': '0.01015500',
#   'askQty': '0.79300000',
#   'openPrice': '0.00989600',
#   'highPrice': '0.01053300',
#   'lowPrice': '0.00986100',
#   'volume': '67149.84600000',
#   'quoteVolume': '677.86712785',
#   'openTime': 1761157605873,
#   'closeTime': 1761244005873,
#   'firstId': 278292494,
#   'lastId': 278415917,
#   'count': 123424}]

# %%
bnc_df = pd.DataFrame.from_dict(bnc.json())
bnc_df
# Out:
#            symbol  priceChange priceChangePercent weightedAvgPrice  \
# 0          ETHBTC  -0.00014000             -0.397       0.03526913
# 1          LTCBTC  -0.00002100             -2.405       0.00085329
# 2          BNBBTC   0.00025900              2.617       0.01009484
# 3          NEOBTC   0.00000033              0.709       0.00004612
# 4         QTUMETH  -0.00000050             -0.099       0.00050592
# ...           ...          ...                ...              ...
# 3358   TURTLEUSDT   0.01180000              6.207       0.18301622
# 3359   TURTLEUSDC   0.01150000              6.043       0.18456760
# 3360    TURTLEBNB   0.00000210              1.182       0.00017396
# 3361  TURTLEFDUSD   0.01210000              6.355       0.18327858
# 3362    TURTLETRY   0.44000000              5.486       7.74962060
#
#      prevClosePrice   lastPrice        lastQty    bidPrice         bidQty  \
# 0        0.03529000  0.03515000     0.00510000  0.03514000    41.17410000
# 1        0.00087300  0.00085200     2.17500000  0.00085100   248.88300000
# 2        0.00989700  0.01015500     0.01900000  0.01015400     3.82800000
# 3        0.00004649  0.00004685    16.55000000  0.00004697   170.22000000
# 4        0.00050590  0.00050430  2542.40000000  0.00050880  1009.00000000
# ...             ...         ...            ...         ...            ...
# 3358     0.19060000  0.20190000   387.20000000  0.20180000  2047.80000000
# 3359     0.19070000  0.20180000   194.00000000  0.20170000   430.10000000
# 3360     0.00017730  0.00017980   196.80000000  0.00017820  2262.10000000
# 3361     0.19040000  0.20250000   196.40000000  0.20140000  1379.60000000
# 3362     8.02000000  8.46000000  8744.70000000  8.47000000  1497.90000000
#
#         askPrice  ...   openPrice   highPrice    lowPrice              volume  \
# 0     0.03515000  ...  0.03529000  0.03561000  0.03476000      19375.91280000
# 1     0.00085200  ...  0.00087300  0.00087800  0.00084100       8893.06300000
# 2     0.01015500  ...  0.00989600  0.01053300  0.00986100      67149.84600000
# 3     0.00004712  ...  0.00004652  0.00004704  0.00004531       6129.78000000
# 4     0.00051070  ...  0.00050480  0.00050770  0.00049920       7400.90000000
# ...          ...  ...         ...         ...         ...                 ...
# 3358  0.20200000  ...  0.19010000  0.22000000  0.15320000  315598429.60000000
# 3359  0.20180000  ...  0.19030000  0.22000000  0.15290000   40514798.40000000
# 3360  0.00018110  ...  0.00017770  0.00020590  0.00012650    1302982.60000000
# 3361  0.20360000  ...  0.19040000  0.22080000  0.15440000     776913.90000000
# 3362  8.48000000  ...  8.02000000  9.23000000  6.45000000  137342901.40000000
#
#               quoteVolume       openTime      closeTime    firstId     lastId  \
# 0            683.37154029  1761157606796  1761244006796  514223484  514304042
# 1              7.58834451  1761157601204  1761244001204  106089638  106094428
# 2            677.86712785  1761157605873  1761244005873  278292494  278415917
# 3              0.28270191  1761157504614  1761243904614   47753400   47753577
# 4              3.74424578  1761157605619  1761244005619    5537971    5538058
# ...                   ...            ...            ...        ...        ...
# 3358    57759633.08615000  1761157607292  1761244007292     544580    1060112
# 3359     7477719.02117000  1761157607148  1761244007148      55702     149252
# 3360         226.66776377  1761157603091  1761244003091       3001       5384
# 3361      142391.67889000  1761157603848  1761244003848       1655       3790
# 3362  1064355377.72300000  1761157605829  1761244005829      78649     206258
#
#        count
# 0      80559
# 1       4791
# 2     123424
# 3        178
# 4         88
# ...      ...
# 3358  515533
# 3359   93551
# 3360    2384
# 3361    2136
# 3362  127610
#
# [3363 rows x 21 columns]

# %%
bnc_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3363 entries, 0 to 3362
# Data columns (total 21 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   symbol              3363 non-null   object
#  1   priceChange         3363 non-null   object
#  2   priceChangePercent  3363 non-null   object
#  3   weightedAvgPrice    3363 non-null   object
#  4   prevClosePrice      3363 non-null   object
#  5   lastPrice           3363 non-null   object
#  6   lastQty             3363 non-null   object
#  7   bidPrice            3363 non-null   object
#  8   bidQty              3363 non-null   object
#  9   askPrice            3363 non-null   object
#  10  askQty              3363 non-null   object
#  11  openPrice           3363 non-null   object
#  12  highPrice           3363 non-null   object
#  13  lowPrice            3363 non-null   object
#  14  volume              3363 non-null   object
#  15  quoteVolume         3363 non-null   object
#  16  openTime            3363 non-null   int64
#  17  closeTime           3363 non-null   int64
#  18  firstId             3363 non-null   int64
#  19  lastId              3363 non-null   int64
#  20  count               3363 non-null   int64
# dtypes: int64(5), object(16)
# memory usage: 551.9+ KB

# %%
bnc_df['priceChangePercent'] = pd.to_numeric(bnc_df['priceChangePercent'])

# %%
bnc_df_top25 = bnc_df.sort_values('priceChangePercent', ascending=False).head(25)
bnc_df_top25.head()
# Out:
#           symbol  priceChange  priceChangePercent weightedAvgPrice  \
# 3071  HYPERFDUSD   0.25030000             242.539       0.39324203
# 1495     RUNEGBP   0.51200000              66.841       1.06056711
# 1306      ADAGBP   0.20280000              65.377       0.45155720
# 2298   CREAMUSDT   0.83000000              65.354       1.49987134
# 1902     NEARRUB  69.00000000              60.315     149.51289073
#
#      prevClosePrice     lastPrice       lastQty    bidPrice      bidQty  \
# 3071     0.00000000    0.35350000  301.50000000  0.00000000  0.00000000
# 1495     0.00000000    1.27800000   65.80000000  0.00000000  0.00000000
# 1306     0.00000000    0.51300000  106.30000000  0.00000000  0.00000000
# 2298     0.00000000    2.10000000   29.44800000  0.00000000  0.00000000
# 1902     0.00000000  183.40000000  302.40000000  0.00000000  0.00000000
#
#         askPrice  ...     openPrice     highPrice      lowPrice  \
# 3071  0.00000000  ...    0.10320000    0.76220000    0.09940000
# 1495  0.00000000  ...    0.76600000    1.40800000    0.62100000
# 1306  0.00000000  ...    0.31020000    0.55370000    0.30630000
# 2298  0.00000000  ...    1.27000000    2.25000000    1.22000000
# 1902  0.00000000  ...  114.40000000  185.10000000  108.50000000
#
#                 volume        quoteVolume       openTime      closeTime  \
# 3071  1748253.10000000    687486.60232000  1759062576527  1759148976527
# 1495   582950.20000000    618257.80860000  1759062576527  1759148976527
# 1306   833927.70000000    376566.05714000  1759062576527  1759148976527
# 2298   184081.17200000    276098.07379000  1759062576527  1759148976527
# 1902   279242.16500000  41750303.30310000  1759062576527  1759148976527
#
#        firstId    lastId  count
# 3071     13997     17996   4000
# 1495    204451    208450   4000
# 1306   4254843   4258842   4000
# 2298  19614262  19618262   4001
# 1902    199469    203468   4000
#
# [5 rows x 21 columns]

# %%
sns.barplot(x='priceChangePercent',
            y="symbol", 
            data=bnc_df_top25, 
            color='c')
# Out:
# <Axes: xlabel='priceChangePercent', ylabel='symbol'>
